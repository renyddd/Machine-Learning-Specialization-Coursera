# %%
import copy, math
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')
np.set_printoptions(precision=2)  # reduced display precision on numpy arrays

# %%
X_train = np.array([[2104, 5, 1, 45], [1416, 3, 2, 40], [852, 2, 1, 35]])
y_train = np.array([460, 232, 178])

# %%
b_init = 785.1811367994083
w_init = np.array([ 0.39133535, 18.75376741, -53.36032453, -26.42131618])

# %%
def predict(x, w, b):
    p = np.dot(x, w) + b
    return p

# %%
def compute_cost(X, y, w, b):
    m = X.shape[0]
    cost = 0.0
    for i in range(m):
        f_wb_i = predict(X[i], w, b)
        cost = cost + (f_wb_i - y[i])**2
    cost = cost / (2 * m)
    return cost

# %%
# compute and display
cost = compute_cost(X_train, y_train, w_init, b_init)
print(f'Cost at optimal w: {cost}')
# Out:
# Cost at optimal w: 1.5578904428966628e-12

# %%
def compute_gradient(X, y, w, b):
    m, n = X.shape
    dj_dw = np.zeros((n,))
    dj_db = 0.
    
    for i in range(m):
        err = predict(X[i], w, b) - y[i]
        for j in range(n):
            dj_dw[j] = dj_dw[j] + err * X[i, j]
        dj_db = dj_db + err
        
    dj_dw = dj_dw / m
    dj_db = dj_db / m
    
    return dj_db, dj_dw

# %%
# compute and display
tmp_dj_db, tmp_dj_dw = compute_gradient(X_train, y_train, w_init, b_init)
print(f'dj_db: {tmp_dj_db}')
print(f'dj_dw: {tmp_dj_dw}')
# Out:
# dj_db: -1.6739251501955248e-06
# dj_dw: [-2.73e-03 -6.27e-06 -2.22e-06 -6.92e-05]

# %%
def gradient_descent_with_hist(X, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters):
    J_history = []
    w_history = []
    b_history = []
    
    w = copy.deepcopy(w_in)
    b = b_in
    
    for i in range(num_iters):
        
        # Calcuate the gradient and update the parameters
        dj_db, dj_dw = gradient_function(X, y, w, b)
        
        # Update parameters using w, b, alpha and gradient
        w = w - alpha * dj_dw
        b = b - alpha * dj_db
        
        # Save cost J at each iteration
        if i < 100000:
            J_history.append(cost_function(X, y, w, b))
            w_history.append(w)
            b_history.append(b)
            
        if i % math.ceil(num_iters / 10) == 0:
            print(f"Iteration {i:4d}: Cost {J_history[-1]:8.2f}    ")
            
    return w, b, J_history, w_history, b_history


def gradient_descent(X, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters):
    w, b, J_history, _, _ = gradient_descent_with_hist(X, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters)
            
    return w, b, J_history

# %% [markdown]
# Test the implementation.

# %%
initial_w = np.zeros_like(w_init)
initial_b = 0.
iterations = 10000
alpha = 6.0e-7

w_final, b_final, J_hist = gradient_descent(X_train, y_train, initial_w, initial_b,
                                           compute_cost, compute_gradient,
                                           alpha, iterations)
print(f"b, w found by gradient descent: {b_final}, {w_final} ")
for i in range(X_train.shape[0]):
    print(f"prediction: {np.dot(X_train[i], w_final) + b_final:0.2f}, target value: {y_train[i]}")
# Out:
# Iteration    0: Cost  9828.53
# Iteration 1000: Cost   684.72
# Iteration 2000: Cost   673.61
# Iteration 3000: Cost   663.61
# Iteration 4000: Cost   654.60
# Iteration 5000: Cost   646.49
# Iteration 6000: Cost   639.18
# Iteration 7000: Cost   632.60
# Iteration 8000: Cost   626.67
# Iteration 9000: Cost   621.32
# b, w found by gradient descent: -0.021922000065046385, [ 0.22  0.04 -0.13 -0.67]
# prediction: 431.25, target value: 460
# prediction: 283.55, target value: 232
# prediction: 163.32, target value: 178

# %% [markdown]
# Plot

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, constrained_layout=True, figsize=(12, 4))
ax1.plot(J_hist)
ax2.plot(np.arange(len(J_hist[-100:])), J_hist[-100:])
ax1.set_title("Cost vs. iteration");  ax2.set_title("Cost vs. iteration (tail)")
ax1.set_ylabel('Cost')             ;  ax2.set_ylabel('Cost') 
ax1.set_xlabel('iteration step')   ;  ax2.set_xlabel('iteration step') 
plt.show()

# %% [markdown]
# ### My explore

# %%
initial_w = np.random.rand(*w_init.shape)
initial_b = 0.
iterations = 10000
alpha = 6.0e-7

w_final, b_final, J_hist, w_hist, b_hist= gradient_descent_with_hist(X_train, y_train, initial_w, initial_b,
                                           compute_cost, compute_gradient,
                                           alpha, iterations)

print(f"b, w found by gradient descent: {b_final}, {w_final} ")
for i in range(X_train.shape[0]):
    print(f"prediction: {np.dot(X_train[i], w_final) + b_final:0.2f}, target value: {y_train[i]}")
# Out:
# Iteration    0: Cost 54956.87
# Iteration 1000: Cost   847.13
# Iteration 2000: Cost   819.55
# Iteration 3000: Cost   794.75
# Iteration 4000: Cost   772.44
# Iteration 5000: Cost   752.37
# Iteration 6000: Cost   734.31
# Iteration 7000: Cost   718.07
# Iteration 8000: Cost   703.46
# Iteration 9000: Cost   690.31
# b, w found by gradient descent: -0.03626260398259381, [ 0.2   1.04  0.24 -0.12]
# prediction: 426.60, target value: 460
# prediction: 285.90, target value: 232
# prediction: 170.88, target value: 178

# %%
fig, axes = plt.subplots(2, 2, constrained_layout=True, figsize=(12, 4))
axes[0][0].plot(J_hist)

p = axes[0][1]
p.plot(b_hist)
p.plot(iterations, b_final, marker='x')
p = axes[1][0]
p.plot(w_hist)

plt.show()

# %% [markdown]
# # Feature scaling and Learning Rate (Multi-variable)

# %%
# show data and learn indexing
data = np.loadtxt("data/houeses.txt", delimiter=',')
X = data[:,:2]
y = data[:,2]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[102], line 2
#       1 # show data and learn indexing
# ----> 2 data = np.loadtxt("./data/houeses.txt", delimiter=',')
#       3 X = data[:,:2]
#       4 y = data[:,2]
#
# File /usr/local/lib/python3.11/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# ...
